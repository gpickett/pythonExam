# %%
import pandas as pd

# %%
import statistics
import datetime

# %%
df = pd.read_csv("./AW_AveMonthSpend.csv")
df2 = pd.read_csv("./AW_BikeBuyer.csv")
df3 = pd.read_csv("./AdvWorksCusts.csv")

# %%
df.head()
# Out:
#    CustomerID  AveMonthSpend
# 0       11000             89
# 1       11001            117
# 2       11002            123
# 3       11003             50
# 4       11004             95

# %%
df.describe()
# Out:
#          CustomerID  AveMonthSpend
# count  16519.000000   16519.000000
# mean   20234.225195      72.405957
# std     5342.515987      27.285370
# min    11000.000000      22.000000
# 25%    15604.500000      52.000000
# 50%    20221.000000      68.000000
# 75%    24860.500000      84.000000
# max    29482.000000     176.000000

# %%
statistics.median(df['AveMonthSpend'])
# Out:
# 68

# %%
statistics.mode(df2['BikeBuyer'])
# Out:
# 0

# %%
df3.groupby(['Occupation']).median()
# Out:
#                 CustomerID  HomeOwnerFlag  NumberCarsOwned  \
# Occupation
# Clerical           20878.0            1.0              1.0
# Management         19685.5            1.0              2.0
# Manual             20794.5            1.0              1.0
# Professional       20216.0            1.0              2.0
# Skilled Manual     20271.0            1.0              1.0
#
#                 NumberChildrenAtHome  TotalChildren  YearlyIncome
# Occupation
# Clerical                         0.0            1.0       49387.0
# Management                       1.0            3.0      118780.0
# Manual                           0.0            1.0       21722.5
# Professional                     1.0            2.0       99046.0
# Skilled Manual                   0.0            1.0       66481.0

# %%
df.joined = pd.merge(df, df2, how='left', on='CustomerID')
df.joined.head()
df.joined = pd.merge(df.joined, df3, how='left', on='CustomerID')
df.joined.head()
df.joined['Age'] = ''
df.joined.to_csv('./orderInfo.csv')

# %%
df.joined.head()
# Out:
#    CustomerID  AveMonthSpend  BikeBuyer Title  FirstName MiddleName LastName  \
# 0       11000             89          0   NaN        Jon          V     Yang
# 1       11001            117          1   NaN     Eugene          L    Huang
# 2       11002            123          0   NaN      Ruben        NaN   Torres
# 3       11003             50          0   NaN    Christy        NaN      Zhu
# 4       11004             95          1   NaN  Elizabeth        NaN  Johnson
#
#   Suffix         AddressLine1 AddressLine2  ...   BirthDate   Education  \
# 0    NaN      3761 N. 14th St          NaN  ...  1966-04-08  Bachelors
# 1    NaN           2243 W St.          NaN  ...  1965-05-14  Bachelors
# 2    NaN     5844 Linden Land          NaN  ...  1965-08-12  Bachelors
# 3    NaN     1825 Village Pl.          NaN  ...  1968-02-15  Bachelors
# 4    NaN  7553 Harness Circle          NaN  ...  1968-08-08  Bachelors
#
#      Occupation Gender MaritalStatus HomeOwnerFlag NumberCarsOwned  \
# ...

# %%
currentYear = 1998
for index, row in df.joined.iterrows():
    x = row['BirthDate'][0:4]
    print(x)
 #   if (currentYear - x <= 25):
 #      row['Age'] = 25
 #   elif (currentYear - x <= 45):
  #     row['Age'] = 45
  #  else:
  #     row['Age'] = 55
# Out:
# 1966
# 1965
# 1965
# 1968
# 1968
# 1965
# 1965
# 1964
# 1964
# 1964
# 1964
# 1963
# 1968
# 1968
# 1968
# 1979
# 1979
# 1978
# 1978
# 1978
# 1978
# 1945
# 1946
# 1946
# 1946
# 1947
# 1947
# 1947
# 1947
# 1948
# 1978
# 1977
# 1975
# 1975
# 1975
# 1975
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1976
# 1949
# 1950
# 1950
# 1950
# 1980
# 1951
# 1951
# 1951
# 1980
# 1952
# 1952
# 1953
# 1953
# 1954
# 1954
# 1954
# 1954
# 1975
# 1975
# 1975
# 1973
# 1973
# 1976
# 1955
# 1955
# 1955
# 1956
# 1956
# 1957
# 1957
# 1957
# 1974
# 1959
# 1959
# 1966
# 1966
# 1966
# 1957
# 1957
# 1957
# 1957
# 1957
# 1957
# 1967
# 1962
# 1962
# 1962
# 1961
# 1961
# 1961
# 1960
# 1965
# 1965
# 1964
# 1964
# 1964
# 1964
# 1959
# 1963
# 1962
# 1962
# 1962
# 1962
# 1973
# 1973
# 1973
# 1973
# 1962
# 1962
# 1961
# 1935
# 1936
# 1960
# 1960
# 1957
# 1956
# 1949
# 1975
# 1975
# 1980
# 1980
# 1980
# 1980
# 1946
# 1979
# 1978
# 1978
# 1978
# 1938
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1979
# 1979
# 1939
# ...

# %%
y = df.joined.iloc[1]['BirthDate']
y[0:4]
# Out:
# '1965'

# %%
# Out:
#   File "<ipython-input-59-d07875d791c5>", line 3
#     df.joined['Age'] = df.joined.apply(lambda row: 25 if currentYear - row['BirthDate'][0:4] <= 25 elif 45 if currentYear - row['BirthDate'][0:4] <= 45 else 55, axis 1)
#                                                                                                       ^
# SyntaxError: invalid syntax

# %%
currentYear = 1998
def func(row):
    return currentYear - int(row['BirthDate'][0:4])


df.joined['Age'] = df.joined.apply(func, axis=1)
df.joined.head()
#df.joined.to_csv('./orderInfoAge.csv')
# Out:
#    CustomerID  AveMonthSpend  BikeBuyer Title  FirstName MiddleName LastName  \
# 0       11000             89          0   NaN        Jon          V     Yang
# 1       11001            117          1   NaN     Eugene          L    Huang
# 2       11002            123          0   NaN      Ruben        NaN   Torres
# 3       11003             50          0   NaN    Christy        NaN      Zhu
# 4       11004             95          1   NaN  Elizabeth        NaN  Johnson
#
#   Suffix         AddressLine1 AddressLine2  ...    Occupation Gender  \
# 0    NaN      3761 N. 14th St          NaN  ...  Professional      M
# 1    NaN           2243 W St.          NaN  ...  Professional      M
# 2    NaN     5844 Linden Land          NaN  ...  Professional      M
# 3    NaN     1825 Village Pl.          NaN  ...  Professional      F
# 4    NaN  7553 Harness Circle          NaN  ...  Professional      F
#
#   MaritalStatus HomeOwnerFlag NumberCarsOwned NumberChildrenAtHome  \
# ...

# %%
df.joined.groupby(['Age', 'Gender']).sum()
# Out:
#             CustomerID  AveMonthSpend  BikeBuyer  HomeOwnerFlag  \
# Age Gender
# 25  F         30458776          72919        347            789
#     M         31734696         114641        390            816
# 45  F        104042820         309401       1720           3591
#     M        106869815         492591       2688           3659
# 55  F         36516647          99177        267           1335
#     M         38005560         158831        293           1386
#
#             NumberCarsOwned  NumberChildrenAtHome  TotalChildren  YearlyIncome
# Age Gender
# 25  F                  2329                   700            734      77728360
#     M                  2404                   595            644      94731952
# 45  F                  6877                  6200          10644     393226353
#     M                  6942                  6395          10874     474289312
# 55  F                  3661                  1581           5801     135878174
# ...

# %%
df.joined.groupby(['MaritalStatus']).median()
# Out:
#                CustomerID  AveMonthSpend  BikeBuyer  HomeOwnerFlag  \
# MaritalStatus
# M                 19720.0           74.0        0.0            1.0
# S                 20908.5           62.0        0.0            1.0
#
#                NumberCarsOwned  NumberChildrenAtHome  TotalChildren  \
# MaritalStatus
# M                          2.0                   0.0            2.0
# S                          1.0                   0.0            1.0
#
#                YearlyIncome   Age
# MaritalStatus
# M                   82185.0  45.0
# S                   68372.0  45.0

# %%
df.joined.groupby(['NumberCarsOwned']).median()
# Out:
#                  CustomerID  AveMonthSpend  BikeBuyer  HomeOwnerFlag  \
# NumberCarsOwned
# 0                   20073.0           65.0        0.0            1.0
# 1                   19845.5           64.0        0.0            1.0
# 2                   20440.5           64.0        0.0            1.0
# 3                   19962.0           92.0        1.0            1.0
# 4                   19915.0          100.0        1.0            1.0
#
#                  NumberChildrenAtHome  TotalChildren  YearlyIncome   Age
# NumberCarsOwned
# 0                                 0.0            1.0       68271.0  45.0
# 1                                 0.0            1.0       63820.0  45.0
# 2                                 0.0            2.0       68076.5  45.0
# 3                                 3.0            4.0      111906.0  45.0
# 4                                 4.0            4.0      133430.0  45.0

# %%
df.joined.groupby(['Gender']).max()
# Out:
#         CustomerID  AveMonthSpend  BikeBuyer FirstName   LastName  \
# Gender
# F            29480            114          1       Zoe  Zimmerman
# M            29482            176          1   Zachary  Zimmerman
#
#            AddressLine1  City StateProvinceName CountryRegionName PostalCode  \
# Gender
# F       Zur Lindung 787  York           Yveline     United States       YO15
# M         Zur Lindung 7  York           Yveline     United States       YO15
#
#         ...   BirthDate            Education      Occupation MaritalStatus  \
# Gender  ...
# F       ...  1980-12-23  Partial High School  Skilled Manual             S
# M       ...  1980-12-26  Partial High School  Skilled Manual             S
#
#        HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  TotalChildren  \
# Gender
# F                  1                4                     5              5
# M                  1                4                     5              5
#
#         YearlyIncome  Age
# ...

# %%
df.joined.head()
# Out:
#    CustomerID  AveMonthSpend  BikeBuyer Title  FirstName MiddleName LastName  \
# 0       11000             89          0   NaN        Jon          V     Yang
# 1       11001            117          1   NaN     Eugene          L    Huang
# 2       11002            123          0   NaN      Ruben        NaN   Torres
# 3       11003             50          0   NaN    Christy        NaN      Zhu
# 4       11004             95          1   NaN  Elizabeth        NaN  Johnson
#
#   Suffix         AddressLine1 AddressLine2  ...    Occupation Gender  \
# 0    NaN      3761 N. 14th St          NaN  ...  Professional      M
# 1    NaN           2243 W St.          NaN  ...  Professional      M
# 2    NaN     5844 Linden Land          NaN  ...  Professional      M
# 3    NaN     1825 Village Pl.          NaN  ...  Professional      F
# 4    NaN  7553 Harness Circle          NaN  ...  Professional      F
#
#   MaritalStatus HomeOwnerFlag NumberCarsOwned NumberChildrenAtHome  \
# ...

# %%
df.joined.groupby(['BikeBuyer']).median()
# Out:
#            CustomerID  AveMonthSpend  HomeOwnerFlag  NumberCarsOwned  \
# BikeBuyer
# 0             20206.5           61.0            1.0              1.0
# 1             20021.0           82.0            1.0              2.0
#
#            NumberChildrenAtHome  TotalChildren  YearlyIncome   Age
# BikeBuyer
# 0                           0.0            1.0       65955.5  45.0
# 1                           2.0            3.0       96273.0  45.0

# %%
df.joined.groupby(['Gender', 'BikeBuyer']).count()
# Out:
#                   CustomerID  AveMonthSpend  Title  FirstName  MiddleName  \
# Gender BikeBuyer
# F      0                6158           6158     30       6158        3591
#        1                2334           2334     14       2334        1353
# M      0                5346           5346     24       5346        3104
#        1                3371           3371     20       3371        1972
#
#                   LastName  Suffix  AddressLine1  AddressLine2  City  ...  \
# Gender BikeBuyer                                                      ...
# F      0              6158       1          6158           111  6158  ...
#        1              2334       0          2334            42  2334  ...
# M      0              5346       0          5346            88  5346  ...
#        1              3371       1          3371            50  3371  ...
#
#                   Education  Occupation  MaritalStatus  HomeOwnerFlag  \
# Gender BikeBuyer
# ...

# %%
df.joined.groupby(['MaritalStatus']).count()
# Out:
#                CustomerID  AveMonthSpend  BikeBuyer  Title  FirstName  \
# MaritalStatus
# M                    9307           9307       9307     44       9307
# S                    7902           7902       7902     44       7902
#
#                MiddleName  LastName  Suffix  AddressLine1  AddressLine2  ...  \
# MaritalStatus                                                            ...
# M                    5426      9307       2          9307           171  ...
# S                    4594      7902       0          7902           120  ...
#
#                Education  Occupation  Gender  HomeOwnerFlag  NumberCarsOwned  \
# MaritalStatus
# M                   9307        9307    9307           9307             9307
# S                   7902        7902    7902           7902             7902
#
#                NumberChildrenAtHome  TotalChildren  YearlyIncome   Age  \
# MaritalStatus
# M                              9307           9307          9307  9307
# ...
